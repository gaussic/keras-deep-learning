# %% [markdown]
# ### 温度预测问题
#
# [数据来源:天气时间序列数据集](https://s3.amazonaws.com/keras-datasets/jena_climate_2009_2016.csv.zip)

# %% [markdown]
# #### 观察数据

# %%
import os

data_dir = 'data/jena_climate'
fname = os.path.join(data_dir, 'jena_climate_2009_2016.csv')

data = open(fname, 'r', encoding='utf-8').read()

lines = data.split('\n')
header = lines[0].split(',')
lines = lines[1:]

print(header)
print(len(lines))
# Out:
# ['"Date Time"', '"p (mbar)"', '"T (degC)"', '"Tpot (K)"', '"Tdew (degC)"', '"rh (%)"', '"VPmax (mbar)"', '"VPact (mbar)"', '"VPdef (mbar)"', '"sh (g/kg)"', '"H2OC (mmol/mol)"', '"rho (g/m**3)"', '"wv (m/s)"', '"max. wv (m/s)"', '"wd (deg)"']
# 420551

# %% [markdown]
# #### 解析数据

# %%
import numpy as np

float_data = np.zeros((len(lines), len(header) - 1))
for i, line in enumerate(lines):
    values = [float(x) for x in line.split(',')[1:]]
    float_data[i, :] = values

# %% [markdown]
# #### 绘制温度时间序列

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
temp = float_data[:, 1]    # 温度(单位:摄氏度)
plt.plot(range(len(temp)), temp)

# %% [markdown]
# #### 绘制前 10 天的温度时间序列
#
# 每 10 分钟记录一次, 每天 144 个数据点

# %%
plt.plot(range(1440), temp[:1440])

# %% [markdown]
# ### 准备数据
#
# #### 数据标准化

# %%
mean = float_data[:200000].mean(axis=0)
float_data -= mean
std = float_data[:200000].std(axis=0)
float_data /= std

# %% [markdown]
# #### 生成时间序列样本及其目标的生成器

# %%
def generator(data, lookback, delay, min_index, max_index, 
              shuffle=True, batch_size=128, step=6):
    if max_index is None:
        max_index = len(data) - delay - 1
    i = min_index + lookback
    while 1:
        if shuffle:
            rows = np.random.randint(min_index + lookback, max_index, size=batch_size)
        else:
            if i + batch_size >= max_index:
                i = min_index + lookback
            rows = np.arange(i, min(i + batch_size, max_index))
            i += len(rows)
            
        samples = np.zeros((len(rows), lookback // step, data.shape[-1]))
        targets = np.zeros((len(rows),))
        for j, row in enumerate(rows):
            indices = range(rows[j] - lookback, rows[j], step)
            samples[j] = data[indices]
            targets[j] = data[rows[j] + delay][1]
        yield samples, targets

# %% [markdown]
# #### 准备训练生成器、验证生成器和测试生成器

# %%
lookback = 1440
step = 6
delay = 144
batch_size = 128

train_gen = generator(float_data, 
                      lookback=lookback, 
                      delay=delay, 
                      min_index=0, 
                      max_index=200000,
                      shuffle=True,
                      step=step, 
                      batch_size=batch_size)
val_gen = generator(float_data, 
                    lookback=lookback, 
                    delay=delay, 
                    min_index=200001, 
                    max_index=300000,
                    step=step, 
                    batch_size=batch_size)
test_gen = generator(float_data, 
                     lookback=lookback, 
                     delay=delay, 
                     min_index=300001, 
                     max_index=None,
                     step=step, 
                     batch_size=batch_size)

# %%
test_gen.__next__()[0].shape
# Out:
# (128, 240, 14)

# %% [markdown]
# 为了查看整个验证集和测试集，需要从 val_gen 和 test_gen 中抽取多少次

# %%
val_steps = (300000 - 200001 - lookback) // batch_size
test_steps = (len(float_data) - 300001 - lookback) // batch_size

# %% [markdown]
# ### 一种基于常识的、非机器学习的基准方法
#
# #### 计算符合常识的基准方法的 MAE

# %%
def evaluate_naive_method():
    batch_maes = []
    for step in range(val_steps):
        samples, targets = next(val_gen)
        preds = samples[:, -1, 1]
        mae = np.mean(np.abs(preds - targets))
        batch_maes.append(mae)
    return np.mean(batch_maes)
    
evaluate_naive_method()
# Out:
# 0.2895349101091901

# %% [markdown]
# #### 将 MAE 转换成摄氏温度误差

# %%
celsius_mae = evaluate_naive_method() * std[1]
celsius_mae
# Out:
# 2.5641271131339405

# %% [markdown]
# ### 一种基本的机器学习方法
#
# #### 训练并评估一个密集连接模型

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.Flatten(input_shape=(lookback // step, float_data.shape[-1])))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3360)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                107552
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 107,585
# Trainable params: 107,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen,
                              steps_per_epoch=500, 
                              epochs=20, 
                              validation_data=val_gen, 
                              validation_steps=val_steps)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 14s 29ms/step - loss: 1.1999 - val_loss: 0.6360
# Epoch 2/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.4903 - val_loss: 0.3700
# Epoch 3/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.3227 - val_loss: 0.3189
# Epoch 4/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2756 - val_loss: 0.2947
# Epoch 5/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2595 - val_loss: 0.3133
# Epoch 6/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2506 - val_loss: 0.3103
# Epoch 7/20
# 500/500 [==============================] - 12s 25ms/step - loss: 0.2420 - val_loss: 0.3108
# Epoch 8/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2347 - val_loss: 0.3503
# Epoch 9/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2315 - val_loss: 0.3148
# Epoch 10/20
# 500/500 [==============================] - 12s 25ms/step - loss: 0.2265 - val_loss: 0.3186
# Epoch 11/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2212 - val_loss: 0.3307
# Epoch 12/20
# 500/500 [==============================] - 12s 25ms/step - loss: 0.2182 - val_loss: 0.3136
# Epoch 13/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2170 - val_loss: 0.3354
# Epoch 14/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2134 - val_loss: 0.3394
# Epoch 15/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2117 - val_loss: 0.3495
# Epoch 16/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2085 - val_loss: 0.3321
# Epoch 17/20
# 500/500 [==============================] - 12s 25ms/step - loss: 0.2066 - val_loss: 0.3275
# Epoch 18/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2056 - val_loss: 0.3616
# Epoch 19/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2037 - val_loss: 0.3248
# Epoch 20/20
# 500/500 [==============================] - 12s 24ms/step - loss: 0.2033 - val_loss: 0.3339

# %% [markdown]
# #### 绘制结果

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 第一个循环网络基准
#
# #### 训练并评估一个基于 GRU 的模型

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.GRU(32, input_shape=(None, float_data.shape[-1])))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 32)                4512
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,545
# Trainable params: 4,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen, 
                              steps_per_epoch=500, 
                              epochs=20, 
                              validation_data=val_gen, 
                              validation_steps=val_steps)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 182s 365ms/step - loss: 0.3038 - val_loss: 0.2721
# Epoch 2/20
# 500/500 [==============================] - 182s 365ms/step - loss: 0.2845 - val_loss: 0.2758
# Epoch 3/20
# 500/500 [==============================] - 182s 363ms/step - loss: 0.2791 - val_loss: 0.2646
# Epoch 4/20
# 500/500 [==============================] - 180s 361ms/step - loss: 0.2742 - val_loss: 0.2630
# Epoch 5/20
# 500/500 [==============================] - 182s 365ms/step - loss: 0.2705 - val_loss: 0.2618
# Epoch 6/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2659 - val_loss: 0.2602
# Epoch 7/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2603 - val_loss: 0.2620
# Epoch 8/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2583 - val_loss: 0.2651
# Epoch 9/20
# 500/500 [==============================] - 183s 365ms/step - loss: 0.2534 - val_loss: 0.2624
# Epoch 10/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2481 - val_loss: 0.2672
# Epoch 11/20
# 500/500 [==============================] - 181s 362ms/step - loss: 0.2438 - val_loss: 0.2737
# Epoch 12/20
# 500/500 [==============================] - 186s 371ms/step - loss: 0.2396 - val_loss: 0.2708
# Epoch 13/20
# 500/500 [==============================] - 183s 366ms/step - loss: 0.2352 - val_loss: 0.2746
# Epoch 14/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2308 - val_loss: 0.2782
# Epoch 15/20
# 500/500 [==============================] - 182s 365ms/step - loss: 0.2252 - val_loss: 0.2818
# Epoch 16/20
# 500/500 [==============================] - 182s 365ms/step - loss: 0.2205 - val_loss: 0.2858
# Epoch 17/20
# 500/500 [==============================] - 183s 367ms/step - loss: 0.2165 - val_loss: 0.2899
# Epoch 18/20
# 500/500 [==============================] - 181s 363ms/step - loss: 0.2145 - val_loss: 0.2898
# Epoch 19/20
# 500/500 [==============================] - 184s 367ms/step - loss: 0.2111 - val_loss: 0.2896
# Epoch 20/20
# 500/500 [==============================] - 182s 364ms/step - loss: 0.2058 - val_loss: 0.2918

# %% [markdown]
# #### 绘制结果

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 使用循环 dropout 来降低过拟合
#
# #### 训练并评估一个使用 dropout 正则化的基于 GRU 的模型

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.GRU(32, 
                     dropout=0.2,
                     recurrent_dropout=0.2,
                     input_shape=(None, float_data.shape[-1])))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_2 (GRU)                  (None, 32)                4512
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,545
# Trainable params: 4,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen, 
                              steps_per_epoch=500, 
                              epochs=40, 
                              validation_data=val_gen, 
                              validation_steps=val_steps)
# Out:
# Epoch 1/40
# 500/500 [==============================] - 208s 417ms/step - loss: 0.3373 - val_loss: 0.2771
# Epoch 2/40
# 500/500 [==============================] - 205s 411ms/step - loss: 0.3146 - val_loss: 0.2727
# Epoch 3/40
# 500/500 [==============================] - 207s 415ms/step - loss: 0.3068 - val_loss: 0.2700
# Epoch 4/40
# 500/500 [==============================] - 207s 413ms/step - loss: 0.3024 - val_loss: 0.2689
# Epoch 5/40
# 500/500 [==============================] - 207s 414ms/step - loss: 0.3018 - val_loss: 0.2630
# Epoch 6/40
# 500/500 [==============================] - 207s 414ms/step - loss: 0.2965 - val_loss: 0.2666
# Epoch 7/40
# 500/500 [==============================] - 207s 414ms/step - loss: 0.2954 - val_loss: 0.2663
# Epoch 8/40
# 500/500 [==============================] - 208s 417ms/step - loss: 0.2930 - val_loss: 0.2672
# Epoch 9/40
# 500/500 [==============================] - 208s 417ms/step - loss: 0.2916 - val_loss: 0.2655
# Epoch 10/40
# 500/500 [==============================] - 210s 421ms/step - loss: 0.2900 - val_loss: 0.2665
# Epoch 11/40
# 500/500 [==============================] - 207s 414ms/step - loss: 0.2898 - val_loss: 0.2650
# Epoch 12/40
# 500/500 [==============================] - 208s 416ms/step - loss: 0.2877 - val_loss: 0.2673
# Epoch 13/40
# 500/500 [==============================] - 207s 413ms/step - loss: 0.2876 - val_loss: 0.2663
# Epoch 14/40
# 500/500 [==============================] - 212s 424ms/step - loss: 0.2867 - val_loss: 0.2632
# Epoch 15/40
# 500/500 [==============================] - 209s 418ms/step - loss: 0.2855 - val_loss: 0.2643
# Epoch 16/40
# 500/500 [==============================] - 207s 414ms/step - loss: 0.2851 - val_loss: 0.2640
# Epoch 17/40
# 500/500 [==============================] - 208s 416ms/step - loss: 0.2841 - val_loss: 0.2621
# Epoch 18/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2803 - val_loss: 0.2682
# Epoch 19/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2812 - val_loss: 0.2660
# Epoch 20/40
# 500/500 [==============================] - 197s 395ms/step - loss: 0.2821 - val_loss: 0.2653
# Epoch 21/40
# 500/500 [==============================] - 197s 395ms/step - loss: 0.2802 - val_loss: 0.2661
# Epoch 22/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2798 - val_loss: 0.2609
# Epoch 23/40
# 500/500 [==============================] - 197s 395ms/step - loss: 0.2804 - val_loss: 0.2634
# Epoch 24/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2792 - val_loss: 0.2635
# Epoch 25/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2769 - val_loss: 0.2641
# Epoch 26/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2771 - val_loss: 0.2654
# Epoch 27/40
# 500/500 [==============================] - 199s 398ms/step - loss: 0.2758 - val_loss: 0.2638
# Epoch 28/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2771 - val_loss: 0.2625
# Epoch 29/40
# 500/500 [==============================] - 198s 396ms/step - loss: 0.2750 - val_loss: 0.2653
# Epoch 30/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2739 - val_loss: 0.2612
# Epoch 31/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2748 - val_loss: 0.2620
# Epoch 32/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2753 - val_loss: 0.2648
# Epoch 33/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2736 - val_loss: 0.2634
# Epoch 34/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2728 - val_loss: 0.2617
# Epoch 35/40
# 500/500 [==============================] - 198s 396ms/step - loss: 0.2730 - val_loss: 0.2649
# Epoch 36/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2719 - val_loss: 0.2656
# Epoch 37/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2718 - val_loss: 0.2658
# Epoch 38/40
# 500/500 [==============================] - 198s 396ms/step - loss: 0.2709 - val_loss: 0.2602
# Epoch 39/40
# 500/500 [==============================] - 198s 395ms/step - loss: 0.2713 - val_loss: 0.2629
# Epoch 40/40
# 500/500 [==============================] - 198s 396ms/step - loss: 0.2711 - val_loss: 0.2672

# %% [markdown]
# #### 绘制结果

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 循环层堆叠
#
# #### 训练并评估一个使用 dropout 正则化的堆叠 GRU 模型

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.GRU(32, 
                    dropout=0.1,
                    recurrent_dropout=0.5, 
                    return_sequences=True, 
                    input_shape=(None, float_data.shape[-1])))
model.add(layers.GRU(64, activation='relu', 
                     dropout=0.1, 
                     recurrent_dropout=0.5))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_3 (GRU)                  (None, None, 32)          4512
# _________________________________________________________________
# gru_4 (GRU)                  (None, 64)                18624
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 23,201
# Trainable params: 23,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen, 
                              steps_per_epoch=500, 
                              epochs=40, 
                              validation_data=val_gen, 
                              validation_steps=val_steps)
# Out:
# Epoch 1/40
# 500/500 [==============================] - 415s 830ms/step - loss: 0.3336 - val_loss: 0.2762
# Epoch 2/40
# 500/500 [==============================] - 414s 828ms/step - loss: 0.3136 - val_loss: 0.2720
# Epoch 3/40
# 500/500 [==============================] - 415s 830ms/step - loss: 0.3082 - val_loss: 0.2714
# Epoch 4/40
# 500/500 [==============================] - 414s 829ms/step - loss: 0.3039 - val_loss: 0.2745
# Epoch 5/40
# 500/500 [==============================] - 414s 829ms/step - loss: 0.2987 - val_loss: 0.2658
# Epoch 6/40
# 500/500 [==============================] - 414s 828ms/step - loss: 0.2973 - val_loss: 0.2695
# Epoch 7/40
# 500/500 [==============================] - 415s 829ms/step - loss: 0.2943 - val_loss: 0.2693
# Epoch 8/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2905 - val_loss: 0.2657
# Epoch 9/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2886 - val_loss: 0.2668
# Epoch 10/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2877 - val_loss: 0.2695
# Epoch 11/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2856 - val_loss: 0.2769
# Epoch 12/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2847 - val_loss: 0.2631
# Epoch 13/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2829 - val_loss: 0.2662
# Epoch 14/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2820 - val_loss: 0.2714
# Epoch 15/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2804 - val_loss: 0.2707
# Epoch 16/40
# 500/500 [==============================] - 411s 821ms/step - loss: 0.2778 - val_loss: 0.2802
# Epoch 17/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2774 - val_loss: 0.2701
# Epoch 18/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2774 - val_loss: 0.2715
# Epoch 19/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2767 - val_loss: 0.2716
# Epoch 20/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2724 - val_loss: 0.2687
# Epoch 21/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2750 - val_loss: 0.2701
# Epoch 22/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2728 - val_loss: 0.2626
# Epoch 23/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2708 - val_loss: 0.2629
# Epoch 24/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2714 - val_loss: 0.2649
# Epoch 25/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2700 - val_loss: 0.2627
# Epoch 26/40
# 500/500 [==============================] - 411s 822ms/step - loss: 0.2694 - val_loss: 0.2674
# Epoch 27/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2689 - val_loss: 0.2638
# Epoch 28/40
# 500/500 [==============================] - 412s 824ms/step - loss: 0.2679 - val_loss: 0.2619
# Epoch 29/40
# 500/500 [==============================] - 412s 824ms/step - loss: 0.2675 - val_loss: 0.2670
# Epoch 30/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2659 - val_loss: 0.2798
# Epoch 31/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2648 - val_loss: 0.2613
# Epoch 32/40
# 500/500 [==============================] - 411s 823ms/step - loss: 0.2654 - val_loss: 0.2597
# Epoch 33/40
# 500/500 [==============================] - 412s 823ms/step - loss: 0.2639 - val_loss: 0.2670
# Epoch 34/40
# 500/500 [==============================] - 17366s 35s/step - loss: 0.2613 - val_loss: 0.2678
# Epoch 35/40
# 500/500 [==============================] - 413s 826ms/step - loss: 0.2627 - val_loss: 0.2674
# Epoch 36/40
# 500/500 [==============================] - 414s 827ms/step - loss: 0.2598 - val_loss: 0.2661
# Epoch 37/40
# 500/500 [==============================] - 413s 826ms/step - loss: 0.2595 - val_loss: 0.2752
# Epoch 38/40
# 500/500 [==============================] - 413s 826ms/step - loss: 0.2580 - val_loss: 0.2656
# Epoch 39/40
# 500/500 [==============================] - 413s 826ms/step - loss: 0.2580 - val_loss: 0.2689
# Epoch 40/40
# 500/500 [==============================] - 413s 826ms/step - loss: 0.2595 - val_loss: 0.2652

# %% [markdown]
# ### 使用双向 RNN
#
# #### 使用逆序序列训练并评估一个 LSTM

# %%
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import layers
from keras.models import Sequential

max_features = 10000
maxlen = 500

# 载入数据
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# 序列反转
x_train = [x[::-1] for x in x_train]
x_test = [x[::-1] for x in x_test]

# 填充序列
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

# 构建模型
model = Sequential()
model.add(layers.Embedding(max_features, 128))
model.add(layers.LSTM(32))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                20608
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,300,641
# Trainable params: 1,300,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.4908 - acc: 0.7660 - val_loss: 0.3543 - val_acc: 0.8658
# Epoch 2/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.3086 - acc: 0.8812 - val_loss: 0.4087 - val_acc: 0.8204
# Epoch 3/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.2588 - acc: 0.9027 - val_loss: 0.3258 - val_acc: 0.8644
# Epoch 4/10
# 20000/20000 [==============================] - 112s 6ms/step - loss: 0.2157 - acc: 0.9218 - val_loss: 0.6198 - val_acc: 0.7910
# Epoch 5/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.1962 - acc: 0.9336 - val_loss: 0.3629 - val_acc: 0.8594
# Epoch 6/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.1822 - acc: 0.9356 - val_loss: 0.3597 - val_acc: 0.8792
# Epoch 7/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.1587 - acc: 0.9451 - val_loss: 0.4216 - val_acc: 0.8702
# Epoch 8/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.1437 - acc: 0.9514 - val_loss: 0.3989 - val_acc: 0.8400
# Epoch 9/10
# 20000/20000 [==============================] - 113s 6ms/step - loss: 0.1304 - acc: 0.9566 - val_loss: 0.3871 - val_acc: 0.8718
# Epoch 10/10
# 20000/20000 [==============================] - 112s 6ms/step - loss: 0.1175 - acc: 0.9603 - val_loss: 0.4993 - val_acc: 0.8726

# %% [markdown]
# #### 训练并评估一个双向 LSTM

# %%
model = Sequential()
model.add(layers.Embedding(max_features, 32))
model.add(layers.Bidirectional(layers.LSTM(32)))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 32)          320000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                16640
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 336,705
# Trainable params: 336,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 232s 12ms/step - loss: 0.5582 - acc: 0.7199 - val_loss: 0.3670 - val_acc: 0.8602
# Epoch 2/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.3757 - acc: 0.8599 - val_loss: 0.3170 - val_acc: 0.8824
# Epoch 3/10
# 20000/20000 [==============================] - 231s 12ms/step - loss: 0.2743 - acc: 0.9018 - val_loss: 0.3574 - val_acc: 0.8754
# Epoch 4/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.2319 - acc: 0.9183 - val_loss: 0.3229 - val_acc: 0.8760
# Epoch 5/10
# 20000/20000 [==============================] - 231s 12ms/step - loss: 0.2089 - acc: 0.9255 - val_loss: 0.3828 - val_acc: 0.8778
# Epoch 6/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.1883 - acc: 0.9369 - val_loss: 0.3505 - val_acc: 0.8772
# Epoch 7/10
# 20000/20000 [==============================] - 231s 12ms/step - loss: 0.1733 - acc: 0.9400 - val_loss: 0.3253 - val_acc: 0.8746
# Epoch 8/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.1543 - acc: 0.9482 - val_loss: 0.4649 - val_acc: 0.8190
# Epoch 9/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.1463 - acc: 0.9491 - val_loss: 0.3594 - val_acc: 0.8672
# Epoch 10/10
# 20000/20000 [==============================] - 230s 12ms/step - loss: 0.1330 - acc: 0.9559 - val_loss: 0.3692 - val_acc: 0.8764

# %% [markdown]
# #### 训练一个双向 GRU

# %%
from keras.models import Sequential
from keras import layers
from keras.optimizers import RMSprop

model = Sequential()
model.add(layers.Bidirectional(
    layers.GRU(32), input_shape=(None, float_data.shape[-1])))
model.add(layers.Dense(1))

model.compile(optimizer=RMSprop(), loss='mae')

# %%
history = model.fit_generator(train_gen, 
                              steps_per_epoch=500, 
                              epochs=40, 
                              validation_data=val_gen, 
                              validation_steps=val_steps)
# Out:
# Epoch 1/40
# 500/500 [==============================] - 351s 702ms/step - loss: 0.2927 - val_loss: 0.2722
# Epoch 2/40
# 500/500 [==============================] - 351s 701ms/step - loss: 0.2756 - val_loss: 0.2753
# Epoch 3/40
# 500/500 [==============================] - 350s 700ms/step - loss: 0.2653 - val_loss: 0.2733
# Epoch 4/40
# 500/500 [==============================] - 359s 718ms/step - loss: 0.2615 - val_loss: 0.2790
# Epoch 5/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2559 - val_loss: 0.2715
# Epoch 6/40
# 500/500 [==============================] - 347s 695ms/step - loss: 0.2509 - val_loss: 0.2800
# Epoch 7/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2453 - val_loss: 0.2802
# Epoch 8/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2392 - val_loss: 0.2805
# Epoch 9/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2323 - val_loss: 0.2882
# Epoch 10/40
# 500/500 [==============================] - 348s 696ms/step - loss: 0.2251 - val_loss: 0.2897
# Epoch 11/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2202 - val_loss: 0.2922
# Epoch 12/40
# 500/500 [==============================] - 348s 695ms/step - loss: 0.2142 - val_loss: 0.2990
# Epoch 13/40
# 500/500 [==============================] - 348s 696ms/step - loss: 0.2093 - val_loss: 0.3050
# Epoch 14/40
# 500/500 [==============================] - 349s 698ms/step - loss: 0.2045 - val_loss: 0.3031
# Epoch 15/40
# 500/500 [==============================] - 355s 710ms/step - loss: 0.2017 - val_loss: 0.3134
# Epoch 16/40
# 500/500 [==============================] - 349s 697ms/step - loss: 0.1963 - val_loss: 0.3121
# Epoch 17/40
# 500/500 [==============================] - 349s 699ms/step - loss: 0.1933 - val_loss: 0.3145
# Epoch 18/40
# 500/500 [==============================] - 351s 701ms/step - loss: 0.1872 - val_loss: 0.3211
# Epoch 19/40
# 500/500 [==============================] - 367s 734ms/step - loss: 0.1834 - val_loss: 0.3232
# Epoch 20/40
# 500/500 [==============================] - 364s 728ms/step - loss: 0.1798 - val_loss: 0.3287
# Epoch 21/40
# 500/500 [==============================] - 370s 740ms/step - loss: 0.1764 - val_loss: 0.3245
# Epoch 22/40
# 500/500 [==============================] - 377s 754ms/step - loss: 0.1745 - val_loss: 0.3267
# Epoch 23/40
# 500/500 [==============================] - 374s 747ms/step - loss: 0.1707 - val_loss: 0.3300
# Epoch 24/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1684 - val_loss: 0.3316
# Epoch 25/40
# 500/500 [==============================] - 377s 755ms/step - loss: 0.1659 - val_loss: 0.3370
# Epoch 26/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1615 - val_loss: 0.3406
# Epoch 27/40
# 500/500 [==============================] - 379s 757ms/step - loss: 0.1592 - val_loss: 0.3382
# Epoch 28/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1574 - val_loss: 0.3394
# Epoch 29/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1546 - val_loss: 0.3395
# Epoch 30/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1527 - val_loss: 0.3420
# Epoch 31/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1490 - val_loss: 0.3491
# Epoch 32/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1481 - val_loss: 0.3429
# Epoch 33/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1469 - val_loss: 0.3531
# Epoch 34/40
# 500/500 [==============================] - 380s 760ms/step - loss: 0.1448 - val_loss: 0.3489
# Epoch 35/40
# 500/500 [==============================] - 378s 757ms/step - loss: 0.1432 - val_loss: 0.3518
# Epoch 36/40
# 500/500 [==============================] - 377s 755ms/step - loss: 0.1414 - val_loss: 0.3458
# Epoch 37/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1404 - val_loss: 0.3462
# Epoch 38/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1390 - val_loss: 0.3452
# Epoch 39/40
# 500/500 [==============================] - 378s 756ms/step - loss: 0.1383 - val_loss: 0.3518
# Epoch 40/40
# 500/500 [==============================] - 378s 755ms/step - loss: 0.1360 - val_loss: 0.3524

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()
