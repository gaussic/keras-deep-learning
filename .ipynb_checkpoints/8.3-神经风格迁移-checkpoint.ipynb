# %% [markdown]
# ### 用 Keras 实现神经风格迁移
#
# #### 定义初始变量

# %%
from keras.preprocessing.image import load_img, img_to_array

# 想要变换的图像的路径
target_image_path = 'images/tubingen.jpg'   
# 风格图像的路径
style_reference_image_path = 'images/starry_night.jpg'

# 生成图像的尺寸
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 辅助函数

# %%
import numpy as np
from keras.applications import vgg19

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %% [markdown]
# #### 加载预训练的 VGG19 网络，并将其应用于三张图像

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))
# 这个占位符用于保存生成图像
combination_image = K.placeholder((1, img_height, img_width, 3))

# 将三张图像合并为一个批量
input_tensor = K.concatenate([target_image, 
                              style_reference_image,
                              combination_image], axis=0)

# 利用三张图像组成的批量作为输入来构建 VGG19 网络。
# 加载模型将使用与训练的 ImageNet 权重
model = vgg19.VGG19(input_tensor=input_tensor, 
                    weights='imagenet',
                    include_top=False)
print('Model loaded.')
# Out:
# Model loaded.

# %% [markdown]
# #### 内容损失

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %% [markdown]
# #### 风格损失

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %% [markdown]
# #### 总变差损失

# %%
def total_variation_loss(x):
    a = K.square(
        x[:, :img_height - 1, :img_width - 1, :] -
        x[:, 1:, :img_width - 1, :])
    b = K.square(
        x[:, :img_height - 1, :img_width - 1, :] -
        x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %% [markdown]
# #### 定义需要最小化的最终损失

# %%
# 将层的名称映射为激活张量的字典
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# 用于内容损失的层
content_layer = 'block5_conv2'
# 用于风格损失的层
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# 损失分量的加权平均所使用的权重
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025

# 添加内容损失
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(target_image_features,
                                            combination_features)

# 添加每个目标层的风格损失分量
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    s1 = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(style_layers)) * s1
    
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %% [markdown]
# #### 设置梯度下降过程

# %%
# 获取损失相对于生成图像的梯度
grads = K.gradients(loss, combination_image)[0]

# 用于获取当前损失值和当前梯度值的函数
fetch_loss_and_grads = K.function([combination_image], [loss, grads])

class Evaluator(object):
    
    def __init__(self):
        self.loss_value = None
        self.grads_values = None
        
    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value
    
    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values
    
evaluator = Evaluator()

# %% [markdown]
# #### 风格迁移循环

# %%
from scipy.optimize import fmin_l_bfgs_b
from imageio import imwrite
import time

result_prefix = 'images/my_result'
iterations = 20

# 这是初始状态：目标图像
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, 
                                     x,
                                     fprime=evaluator.grads, 
                                     maxfun=20)
    print('Current loss value:', min_val)
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imwrite(fname, img)
    print('Image saved as', fname)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1531846500.0
# Image saved as images/my_result_at_iteration_0.png
# Iteration 0 completed in 11s
# Start of iteration 1
# Current loss value: 578577600.0
# Image saved as images/my_result_at_iteration_1.png
# Iteration 1 completed in 11s
# Start of iteration 2
# Current loss value: 335194430.0
# Image saved as images/my_result_at_iteration_2.png
# Iteration 2 completed in 11s
# Start of iteration 3
# Current loss value: 251743520.0
# Image saved as images/my_result_at_iteration_3.png
# Iteration 3 completed in 11s
# Start of iteration 4
# Current loss value: 204143800.0
# Image saved as images/my_result_at_iteration_4.png
# Iteration 4 completed in 11s
# Start of iteration 5
# Current loss value: 176541020.0
# Image saved as images/my_result_at_iteration_5.png
# Iteration 5 completed in 11s
# Start of iteration 6
# Current loss value: 159762660.0
# Image saved as images/my_result_at_iteration_6.png
# Iteration 6 completed in 11s
# Start of iteration 7
# Current loss value: 132538340.0
# Image saved as images/my_result_at_iteration_7.png
# Iteration 7 completed in 11s
# Start of iteration 8
# Current loss value: 118331250.0
# Image saved as images/my_result_at_iteration_8.png
# Iteration 8 completed in 11s
# Start of iteration 9
# Current loss value: 109632130.0
# Image saved as images/my_result_at_iteration_9.png
# Iteration 9 completed in 11s
# Start of iteration 10
# Current loss value: 101821544.0
# Image saved as images/my_result_at_iteration_10.png
# Iteration 10 completed in 11s
# Start of iteration 11
# Current loss value: 96957096.0
# Image saved as images/my_result_at_iteration_11.png
# Iteration 11 completed in 11s
# Start of iteration 12
# Current loss value: 91695896.0
# Image saved as images/my_result_at_iteration_12.png
# Iteration 12 completed in 11s
# Start of iteration 13
# Current loss value: 87471620.0
# Image saved as images/my_result_at_iteration_13.png
# Iteration 13 completed in 11s
# Start of iteration 14
# Current loss value: 84336960.0
# Image saved as images/my_result_at_iteration_14.png
# Iteration 14 completed in 11s
# Start of iteration 15
# Current loss value: 81941440.0
# Image saved as images/my_result_at_iteration_15.png
# Iteration 15 completed in 11s
# Start of iteration 16
# Current loss value: 79782840.0
# Image saved as images/my_result_at_iteration_16.png
# Iteration 16 completed in 11s
# Start of iteration 17
# Current loss value: 77740344.0
# Image saved as images/my_result_at_iteration_17.png
# Iteration 17 completed in 11s
# Start of iteration 18
# Current loss value: 75501130.0
# Image saved as images/my_result_at_iteration_18.png
# Iteration 18 completed in 11s
# Start of iteration 19
# Current loss value: 73443380.0
# Image saved as images/my_result_at_iteration_19.png
# Iteration 19 completed in 11s

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()
